# %%
import pandas as pd

# %%
df =pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64461 entries, 1 to 65112
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    64162 non-null  object
#  1   Hobbyist                      64416 non-null  object
#  2   Age                           45446 non-null  float64
#  3   Age1stCode                    57900 non-null  object
#  4   CompFreq                      40069 non-null  object
#  5   CompTotal                     34826 non-null  float64
#  6   ConvertedComp                 34756 non-null  float64
#  7   Country                       64072 non-null  object
#  8   CurrencyDesc                  45472 non-null  object
#  9   CurrencySymbol                45472 non-null  object
#  10  DatabaseDesireNextYear        44070 non-null  object
#  11  DatabaseWorkedWith            49537 non-null  object
# ...

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
filtar_us = (df['Country'] == 'United States') #se usa de este modo el filtro para que sea mejor leido

# %%
df[filtar_us].head(5) #llama a la variable donde se almacena el filtro con la capsula
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 8                              I am a developer by profession      Yes  36.0
# 14                             I am a developer by profession      Yes  27.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# Respondent
# 5                  16      NaN        NaN            NaN  United States
# 8                  12   Yearly   116000.0       116000.0  United States
# 14                 13   Yearly    66000.0        66000.0  United States
# 17                 14   Yearly    79000.0        79000.0  United States
# 18                 12  Monthly   105000.0      1260000.0  United States
#
# ...

# %%
#Tambiem puedes usar la varible de filtro con .loc, ademas le agregas la coma para ver solo una colunma en especifico por el primer valor filtrado
filtar_us2 = (df['Country'] == 'United States') & (df['Hobbyist'] == 'Yes') #variable con el And &

#Filtrado por paises
countries = ['United States', 'India','United Kingdom','Germany', 'Canada'] #se creo una lista para hacer el llamado a DF y filtar por esos paises 
filt_countries = df['Country'].isin(countries) # con la condicion isin llama al listado deseas agragar para hacer el filtro 


#Operadores ><
high_salary = (df['ConvertedComp'] > 70000) # mayor que 
low_salary = (df['ConvertedComp'] < 70000) & (df['CurrencySymbol'] == 'GBP') # menor que

#str contienes incluye sacar los valores nulos or NA
Leng_work = df['LanguageWorkedWith'].str.contains('Python', na=False)

# no NAN value column 
compensaion_na = (df['ConvertedComp'].notna()) & (df['LanguageWorkedWith'].notna())

# %%
df.loc[compensaion_na,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                                          Country  \
# Respondent
# 8                                  United States
# 10                                United Kingdom
# 11                                United Kingdom
# 12                                         Spain
# 13                                   Netherlands
# ...                                          ...
# 65571                                  Australia
# 65584                                      India
# 65595       Venezuela, Bolivarian Republic of...
# 65596                              United States
# 65619                                    Nigeria
#
#                                            LanguageWorkedWith  ConvertedComp
# Respondent
# 8                                                  Python;SQL       116000.0
# 10                        HTML/CSS;Java;JavaScript;Python;SQL        32315.0
# 11                                        C#;JavaScript;Swift        40070.0
# ...

# %%
# operadores And(&), Or (|)
df[filtar_us2] #llama a la variable donde se almacena el filtro con la capsula
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 8                              I am a developer by profession      Yes  36.0
# 14                             I am a developer by profession      Yes  27.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# ...                                                       ...      ...   ...
# 58498                                                     NaN      Yes  32.0
# 58896                                                     NaN      Yes  29.0
# 60931                                                     NaN      Yes   NaN
# 63077                                                     NaN      Yes   NaN
# 64858                                                     NaN      Yes   NaN
#
# ...

# %%
df.loc[Leng_work, 'LanguageWorkedWith']
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %%
df[high_salary].head(3)
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 8           I am a developer by profession      Yes  36.0         12   Yearly
# 16          I am a developer by profession      Yes  45.0          8  Monthly
# 17          I am a developer by profession      Yes  25.0         14   Yearly
#
#             CompTotal  ConvertedComp         Country          CurrencyDesc  \
# Respondent
# 8            116000.0       116000.0   United States  United States dollar
# 16             7000.0       108576.0  United Kingdom        Pound sterling
# 17            79000.0        79000.0   United States  United States dollar
#
#            CurrencySymbol  ... SurveyEase           SurveyLength Trans  \
# Respondent                 ...
# 8                     USD  ...       Easy  Appropriate in length    No
# 16                    GBP  ...       Easy  Appropriate in length    No
# 17                    USD  ...       Easy  Appropriate in length    No
#
# ...

# %%
df[low_salary].head(3)
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 10          I am a developer by profession      Yes  22.0         14   Yearly
# 11          I am a developer by profession      Yes  23.0         13   Yearly
# 30          I am a developer by profession      Yes   NaN         14   Yearly
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 10            25000.0        32315.0  United Kingdom  Pound sterling
# 11            31000.0        40070.0  United Kingdom  Pound sterling
# 30            30000.0        38778.0  United Kingdom  Pound sterling
#
#            CurrencySymbol  ...                  SurveyEase  \
# Respondent                 ...
# 10                    GBP  ...                        Easy
# 11                    GBP  ...                        Easy
# 30                    GBP  ...  Neither easy nor difficult
#
#                      SurveyLength Trans  \
# Respondent
# ...

# %%
df[low_salary].sort_index(ascending =False)
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 65598       I am not primarily a developer, but I write co...      Yes   NaN
# 65143                          I am a developer by profession      Yes   NaN
# 65101                          I am a developer by profession       No   NaN
# 64733                          I am a developer by profession      Yes   NaN
# 63896                          I am a developer by profession      Yes   NaN
# ...                                                       ...      ...   ...
# 145         I am not primarily a developer, but I write co...      Yes  26.0
# 70                             I am a developer by profession      Yes  25.0
# 30                             I am a developer by profession      Yes   NaN
# 11                             I am a developer by profession      Yes  23.0
# 10                             I am a developer by profession      Yes  22.0
#
# ...

# %%
df.loc[low_salary, ['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 10          United Kingdom                HTML/CSS;Java;JavaScript;Python;SQL
# 11          United Kingdom                                C#;JavaScript;Swift
# 30          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 70          United Kingdom                        HTML/CSS;JavaScript;PHP;SQL
# 145         United Kingdom                       Bash/Shell/PowerShell;Python
# ...                    ...                                                ...
# 63896       United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 64733       United Kingdom                      C;C#;C++;Java;Kotlin;Python;R
# 65101       United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# 65143       United Kingdom                                                NaN
# 65598       United Kingdom                                                NaN
#
# ...
