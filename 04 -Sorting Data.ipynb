# %%
import pandas as pd

# %%
ct = pd.read_csv('data/Contactos.csv')

# %%
ct
# Out:
#   Firth name  Last name Working
# 0    Eduardo       Lowe     yes
# 1     George     Benson     yes
# 2     Olivia     Fuller     yes
# 3       Noah   Mccarthy     yes
# 4     Oliver     Bowman      no
# 5    William      Marsh      no
# 6     Abdiel  Rodriguez      no

# %%
# Sortting Data
ct.sort_values(by='Last name')
# Out:
#   Firth name  Last name Working
# 1     George     Benson     yes
# 4     Oliver     Bowman      no
# 2     Olivia     Fuller     yes
# 0    Eduardo       Lowe     yes
# 5    William      Marsh      no
# 3       Noah   Mccarthy     yes
# 6     Abdiel  Rodriguez      no

# %%
# Sortting Data desendetes forma
ct.sort_values(by='Last name', ascending=False)
# Out:
#   Firth name  Last name Working
# 6     Abdiel  Rodriguez      no
# 3       Noah   Mccarthy     yes
# 5    William      Marsh      no
# 0    Eduardo       Lowe     yes
# 2     Olivia     Fuller     yes
# 4     Oliver     Bowman      no
# 1     George     Benson     yes

# %%
# Sortting Data desendetes por orden de colunma 
ct.sort_values(by=['Last name','Firth name'], ascending=[False,True], inplace=True)

# %%
ct
# Out:
#   Firth name  Last name Working
# 6     Abdiel  Rodriguez      no
# 3       Noah   Mccarthy     yes
# 5    William      Marsh      no
# 0    Eduardo       Lowe     yes
# 2     Olivia     Fuller     yes
# 4     Oliver     Bowman      no
# 1     George     Benson     yes

# %%
ct.sort_index()
# Out:
#   Firth name  Last name Working
# 0    Eduardo       Lowe     yes
# 1     George     Benson     yes
# 2     Olivia     Fuller     yes
# 3       Noah   Mccarthy     yes
# 4     Oliver     Bowman      no
# 5    William      Marsh      no
# 6     Abdiel  Rodriguez      no

# %%
ct['Last name'].sort_values()
# Out:
# 1       Benson
# 4       Bowman
# 2       Fuller
# 0         Lowe
# 5        Marsh
# 3     Mccarthy
# 6    Rodriguez
# Name: Last name, dtype: object
