# %%
import pandas as pd

# %%
df =pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
df.head(3)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
# 3              I code primarily as a hobby      Yes  NaN         15      NaN
#
#             CompTotal  ConvertedComp             Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN             Germany   European Euro
# 2                 NaN            NaN      United Kingdom  Pound sterling
# 3                 NaN            NaN  Russian Federation             NaN
#
#            CurrencySymbol  ...                  SurveyEase  \
# Respondent                 ...
# 1                     EUR  ...  Neither easy nor difficult
# 2                     GBP  ...                         NaN
# 3                     NaN  ...  Neither easy nor difficult
#
#                      SurveyLength Trans  \
# Respondent
# ...

# %%
schema_df
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
schema_df.sort_index(ascending=False) #ordenar de manera asendente true or false argument, para la visualizacion de las colunmas
# Out:
#                                                          QuestionText
# Column
# YearsCodePro        NOT including education, how many years have y...
# YearsCode           Including any education, how many years have y...
# WorkWeekHrs         On average, how many hours per week do you wor...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# ...                                                               ...
# ConvertedComp       Salary converted to annual USD salaries using ...
# CompTotal           What is your current total compensation (salar...
# CompFreq             Is that compensation weekly, monthly, or yearly?
# Age1stCode          At what age did you write your first line of c...
# Age                 What is your age (in years)? If you prefer not...
#
# [61 rows x 1 columns]

# %%
df.set_index('WebframeWorkedWith', inplace=True) #aplicando el indice a la colunma indica en la sentencia

# %%
df.index
# Out:
# Index([                  'ASP.NET;ASP.NET Core',
#                                             nan,
#                                             nan,
#                                             nan,
#                                 'Ruby on Rails',
#                                             nan,
#                                             nan,
#                                         'Flask',
#                                        'jQuery',
#                                  'Flask;jQuery',
#        ...
#                                             nan,
#                                             nan,
#                                             nan,
#                                             nan,
#                                  'ASP.NET Core',
#                                             nan,
#                                             nan,
#                                             nan,
#                                             nan,
# ...

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df.loc['ASP.NET Core']
# Out:
#                                                 MainBranch Hobbyist   Age  \
# WebframeWorkedWith
# ASP.NET Core                I am a developer by profession      Yes  33.0
# ASP.NET Core        I am a student who is learning to code      Yes  19.0
# ASP.NET Core                I am a developer by profession       No  30.0
# ASP.NET Core                I am a developer by profession      Yes  32.0
# ASP.NET Core                I am a developer by profession      Yes  23.0
# ...                                                    ...      ...   ...
# ASP.NET Core                I am a developer by profession      Yes   NaN
# ASP.NET Core                I am a developer by profession       No   NaN
# ASP.NET Core        I am a student who is learning to code       No   NaN
# ASP.NET Core        I am a student who is learning to code      Yes   NaN
# ASP.NET Core                                           NaN      Yes   NaN
#
# ...

# %%
df.reset_index(inplace=True) 
df.head(3)
# Out:
#      WebframeWorkedWith                      MainBranch Hobbyist  Age  \
# 0  ASP.NET;ASP.NET Core  I am a developer by profession      Yes  NaN
# 1                   NaN  I am a developer by profession       No  NaN
# 2                   NaN     I code primarily as a hobby      Yes  NaN
#
#   Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0         13  Monthly        NaN            NaN             Germany
# 1         19      NaN        NaN            NaN      United Kingdom
# 2         15      NaN        NaN            NaN  Russian Federation
#
#      CurrencyDesc  ...             SOVisitFreq                  SurveyEase  \
# 0   European Euro  ...  Multiple times per day  Neither easy nor difficult
# 1  Pound sterling  ...  Multiple times per day                         NaN
# 2             NaN  ...   Daily or almost daily  Neither easy nor difficult
#
#             SurveyLength Trans  \
# 0  Appropriate in length    No
# 1                    NaN   NaN
# ...
